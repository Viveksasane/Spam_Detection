# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"D:\Machine_Learning_Projects\Spam_detection\data\spam_email_dataset.csv")

# %%
data
# Out:
#       email_id                subject  \
# 0            0          Weekly Report
# 1            1         Project Update
# 2            2         🔥WIN BIG NOW!!
# 3            3         🔥WIN BIG NOW!!
# 4            4       Meeting Reminder
# ...        ...                    ...
# 9995      9995         🔥WIN BIG NOW!!
# 9996      9996    You are selected!!!
# 9997      9997    You are selected!!!
# 9998      9998       Meeting Reminder
# 9999      9999  Schedule Confirmation
#
#                                              email_text  num_words  \
# 0     budget review - Statement our I claim world st...         19
# 1     team sync - President series today already. In...         18
# 2     win free urgent offer limited limited urgent u...         19
# 3     guarantee click now cash offer click now guara...         16
# 4     team sync - Significant property hotel not add...         18
# ...                                                 ...        ...
# ...

# %%
clean_data=data[["subject","email_text","label"]]

# %%
clean_data
# Out:
#                     subject  \
# 0             Weekly Report
# 1            Project Update
# 2            🔥WIN BIG NOW!!
# 3            🔥WIN BIG NOW!!
# 4          Meeting Reminder
# ...                     ...
# 9995         🔥WIN BIG NOW!!
# 9996    You are selected!!!
# 9997    You are selected!!!
# 9998       Meeting Reminder
# 9999  Schedule Confirmation
#
#                                              email_text  label
# 0     budget review - Statement our I claim world st...      0
# 1     team sync - President series today already. In...      0
# 2     win free urgent offer limited limited urgent u...      1
# 3     guarantee click now cash offer click now guara...      1
# 4     team sync - Significant property hotel not add...      0
# ...                                                 ...    ...
# 9995  free win cash win guarantee urgent free win li...      1
# 9996  click now free guarantee free win click now wi...      1
# ...

# %%
clean_data["cleaned"]=clean_data["subject"] + " " + clean_data["email_text"]
# Out:
# C:\Users\Vivek\AppData\Local\Temp\ipykernel_21440\2808914679.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data["cleaned"]=clean_data["subject"] + " " + clean_data["email_text"]

# %%
clean_data
# Out:
#                     subject  \
# 0             Weekly Report
# 1            Project Update
# 2            🔥WIN BIG NOW!!
# 3            🔥WIN BIG NOW!!
# 4          Meeting Reminder
# ...                     ...
# 9995         🔥WIN BIG NOW!!
# 9996    You are selected!!!
# 9997    You are selected!!!
# 9998       Meeting Reminder
# 9999  Schedule Confirmation
#
#                                              email_text  label  \
# 0     budget review - Statement our I claim world st...      0
# 1     team sync - President series today already. In...      0
# 2     win free urgent offer limited limited urgent u...      1
# 3     guarantee click now cash offer click now guara...      1
# 4     team sync - Significant property hotel not add...      0
# ...                                                 ...    ...
# 9995  free win cash win guarantee urgent free win li...      1
# 9996  click now free guarantee free win click now wi...      1
# ...

# %%
clean_data=clean_data[["cleaned","label"]]

# %%
clean_data
# Out:
#                                                 cleaned  label
# 0     Weekly Report budget review - Statement our I ...      0
# 1     Project Update team sync - President series to...      0
# 2     🔥WIN BIG NOW!! win free urgent offer limited l...      1
# 3     🔥WIN BIG NOW!! guarantee click now cash offer ...      1
# 4     Meeting Reminder team sync - Significant prope...      0
# ...                                                 ...    ...
# 9995  🔥WIN BIG NOW!! free win cash win guarantee urg...      1
# 9996  You are selected!!! click now free guarantee f...      1
# 9997  You are selected!!! offer cash win limited cli...      1
# 9998  Meeting Reminder budget review - Many result a...      0
# 9999  Schedule Confirmation budget review - Day meas...      0
#
# [10000 rows x 2 columns]

# %%
clean_data.to_csv(r"D:\Machine_Learning_Projects\Spam_detection\data\data_clean.csv", index=False)
